# %%
from ok_palette_lab_tools.color_maps.color_map_def import (
    load_color_maps_def,
)
from ok_palette_lab_tools.color_maps.generate_color_map import (
    generate_color_map,
)
from ok_palette_lab_tools.color_maps.tests.cyclic.test_figures import (
    create_color_map_image,
    create_arctan_2d,
)

# %% [markdown]
# ## Color map to be tested

# %%
color_map_name = "equal_hue"

# %% [markdown]
# ## Generate color map

# %%
color_maps = load_color_maps_def()
color_scale_for_plotly = generate_color_map(
    color_maps[color_map_name]
).colors
color_scale_for_plotly

# %%
create_color_map_image(color_map=color_scale_for_plotly)

# %% [markdown]
# ## arctan function in 2D

# %%
create_arctan_2d(color_map=color_scale_for_plotly)
