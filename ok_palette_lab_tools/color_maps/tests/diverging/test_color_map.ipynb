# %%
from ok_palette_lab_tools.color_maps.color_map_def import (
    load_color_maps_def,
)
from ok_palette_lab_tools.color_maps.generate_color_map import (
    generate_color_map,
)
from ok_palette_lab_tools.color_maps.tests.diverging.test_figures import (
    create_color_map_image,
    create_gaussian,
    create_peaks,
    create_perlin_noise,
    create_spiral_pattern,
)
import plotly.io

# %% [markdown]
# ## Color map to be tested

# %%
color_map_name = "blue_brown_light"
plotly.io.templates.default = "plotly_white"
# plotly.io.templates.default = "plotly_dark"

# %% [markdown]
# ## Generate color map

# %%
color_maps = load_color_maps_def()
color_scale_for_plotly = generate_color_map(color_maps[color_map_name]).colors
color_scale_for_plotly

# %%
create_color_map_image(color_map=color_scale_for_plotly)

# %% [markdown]
# ## Gaussian

# %%
create_gaussian(color_map=color_scale_for_plotly)

# %% [markdown]
# ## Peaks in MATLAB

# %%
create_peaks(color_map=color_scale_for_plotly)

# %% [markdown]
# ## Perlin noise

# %%
create_perlin_noise(color_map=color_scale_for_plotly)

# %% [markdown]
# ## Spiral pattern

# %%
create_spiral_pattern(color_map=color_scale_for_plotly)
